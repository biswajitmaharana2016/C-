# %% [markdown]
# <a href="https://colab.research.google.com/github/biswajitmaharana2016/C-/blob/master/Pandas22ndJune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# !pip install numpy

# %%
s1 = pd.Series([1,2,3,4,5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1.shape
# Out:
# (5,)

# %%
s1.size
# Out:
# 5

# %%
s1.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(s1.values)
# Out:
# numpy.ndarray

# %%
s2= pd.Series([1,2+1j,'krishna',40.5,5+2j], index=['a','b','c','d','e'])
s2
# Out:
# a          1
# b     (2+1j)
# c    krishna
# d       40.5
# e     (5+2j)
# dtype: object

# %%
s2[0:3]
# Out:
# a          1
# b     (2+1j)
# c    krishna
# dtype: object

# %%
s2['a':'c']
# Out:
# a          1
# b     (2+1j)
# c    krishna
# dtype: object

# %%
s2['c']= s2['c'] + 'mohan'
s2
# Out:
# a                    1
# b               (2+1j)
# c    krishnamohanmohan
# d                 40.5
# e               (5+2j)
# dtype: object

# %%
type(s2)
# Out:
# pandas.core.series.Series

# %%
s1[(s1 >2) & (s1 < 5)]
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
s1[(s1 >=2) | (s1 <= 5)]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1[~(s1 > 2)]
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
data = {
    'name': ['Raja', 'Rakesh','Rana','Lakshmi', 'Mario'],
    'city': ['Munich','Hmburg','Blore','Hyd','Delhi'],
    'job': ['Admin','Dev','Arch','CTO','Manager']
}
df1 = pd.DataFrame(data)
df1
# Out:
#       name    city      job
# 0     Raja  Munich    Admin
# 1   Rakesh  Hmburg      Dev
# 2     Rana   Blore     Arch
# 3  Lakshmi     Hyd      CTO
# 4    Mario   Delhi  Manager

# %%
df1['name'][0]
# Out:
# 'Raja'

# %%
df1.city[0]
# Out:
# 'Munich'

# %%
df1.columns =['name of per', 'city', 'job']

# %%
df1
# Out:
#   name of per    city      job
# 0        Raja  Munich    Admin
# 1      Rakesh  Hmburg      Dev
# 2        Rana   Blore     Arch
# 3     Lakshmi     Hyd      CTO
# 4       Mario   Delhi  Manager

# %%
df1.rename(columns={'name of per':'name'}, inplace=True)

# %%
df1
# Out:
#       name    city      job
# 0     Raja  Munich    Admin
# 1   Rakesh  Hmburg      Dev
# 2     Rana   Blore     Arch
# 3  Lakshmi     Hyd      CTO
# 4    Mario   Delhi  Manager

# %%
df1[['name', 'job','city']]
# Out:
#       name      job    city
# 0     Raja    Admin  Munich
# 1   Rakesh      Dev  Hmburg
# 2     Rana     Arch   Blore
# 3  Lakshmi      CTO     Hyd
# 4    Mario  Manager   Delhi

# %%
df1.loc[0]
# Out:
# name      Raja
# city    Munich
# job      Admin
# Name: 0, dtype: object

# %%
df1.iloc[2]['name']
# Out:
# 'Rana'

# %%
df1.index =['a','b','c','d','e']

# %%
df1
# Out:
#       name    city      job
# a     Raja  Munich    Admin
# b   Rakesh  Hmburg      Dev
# c     Rana   Blore     Arch
# d  Lakshmi     Hyd      CTO
# e    Mario   Delhi  Manager

# %%
df1.loc['a']['name'] # loc function can be any thing other than integer
# Out:
# 'Raja'

# %%
df1.query('name == "Raja"' and 'city == "Munich"')
# Out:
#    name    city    job
# a  Raja  Munich  Admin

# %%
df1["salary"]=[1000,2000,3000,4000,5000]

# %%
df1
# Out:
#       name    city      job  salary
# a     Raja  Munich    Admin    1000
# b   Rakesh  Hmburg      Dev    2000
# c     Rana   Blore     Arch    3000
# d  Lakshmi     Hyd      CTO    4000
# e    Mario   Delhi  Manager    5000

# %%
cond1 = df1['salary'] > 2000
cond2 = df1['salary'] < 5000

# %%
df1[cond1 & cond2]
# Out:
#       name   city   job  salary
# c     Rana  Blore  Arch    3000
# d  Lakshmi    Hyd   CTO    4000

# %%
name_list = ['Raja','Mario']
df1[df1['name'].isin(name_list)]
# Out:
#     name    city      job  salary
# a   Raja  Munich    Admin    1000
# e  Mario   Delhi  Manager    5000

# %%
df1[df1.name.str.startswith('R')]
# Out:
#      name    city    job  salary
# a    Raja  Munich  Admin    1000
# b  Rakesh  Hmburg    Dev    2000
# c    Rana   Blore   Arch    3000

# %%
df1.name.str.upper

# %%
df1[df1.salary == df1.salary.max()]
# Out:
#     name   city      job  salary
# e  Mario  Delhi  Manager    5000

# %%
df1.sort_values(by='salary', ascending=False)
# Out:
#       name    city      job  salary
# e    Mario   Delhi  Manager    5000
# d  Lakshmi     Hyd      CTO    4000
# c     Rana   Blore     Arch    3000
# b   Rakesh  Hmburg      Dev    2000
# a     Raja  Munich    Admin    1000

# %%
df1.reset_index()
# Out:
#   index     name    city      job  salary
# 0     a     Raja  Munich    Admin    1000
# 1     b   Rakesh  Hmburg      Dev    2000
# 2     c     Rana   Blore     Arch    3000
# 3     d  Lakshmi     Hyd      CTO    4000
# 4     e    Mario   Delhi  Manager    5000

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Berlin', 'Paris', 'London']
})

# Save to CSV
df.to_csv('output.csv', index=False)

# %%
df.to_json('output.json')

# %%
df.to_excel('output.xlsx', index=False)

# %%
pd.read_csv('output.csv')
# Out:
#       Name  Age    City
# 0    Alice   25  Berlin
# 1      Bob   30   Paris
# 2  Charlie   35  London

# %%
pd.read_table('output.csv', sep=',')
# Out:
#       Name  Age    City
# 0    Alice   25  Berlin
# 1      Bob   30   Paris
# 2  Charlie   35  London

# %%
pd.read_json('output.json')
# Out:
#       Name  Age    City
# 0    Alice   25  Berlin
# 1      Bob   30   Paris
# 2  Charlie   35  London

# %%
pd.read_excel('output.xlsx')
# Out:
#       Name  Age    City
# 0    Alice   25  Berlin
# 1      Bob   30   Paris
# 2  Charlie   35  London

# %%
df2 =pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df2.to_csv('titanic.csv', index=False)

# %%
pd.read_csv('titanic.csv', index_col='PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
ship = pd.read_csv('titanic.csv')
ship
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2= pd.read_csv('titanic.csv', usecols=['PassengerId','Survived','Pclass'])

# %%
df2.insert(2,'Harris',ship.Name)

# %%
df.insert(2,'Biswajit',ship.Name)

# %%
ship.insert(2,'Biswajit',ship.Name)

# %%
ship
# Out:
#      PassengerId  Survived                                           Biswajit  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
ship.columns
# Out:
# Index(['PassengerId', 'Survived', 'Biswajit', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
ship.drop('Embarked', axis=1, inplace=True)

# %%
ship.columns
# Out:
# Index(['PassengerId', 'Survived', 'Biswajit', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin'],
#       dtype='object')

# %%
ship.drop(4, axis=0, inplace=True)

# %%
ship
# Out:
#      PassengerId  Survived                                           Biswajit  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5              6         0                                   Moran, Mr. James
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
ship.reset_index(drop=True, inplace=True)

# %%
ship
# Out:
#      PassengerId  Survived                                           Biswajit  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              6         0                                   Moran, Mr. James
# ..           ...       ...                                                ...
# 885          887         0                              Montvila, Rev. Juozas
# 886          888         1                       Graham, Miss. Margaret Edith
# 887          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 888          890         1                              Behr, Mr. Karl Howell
# 889          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
ship.columns
# Out:
# Index(['PassengerId', 'Survived', 'Biswajit', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin'],
#       dtype='object')

# %%
ship.drop(['Survived'], axis=1, inplace=True)

# %%
ship.columns
# Out:
# Index(['PassengerId', 'Biswajit', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin'],
#       dtype='object')

# %%
ship.drop(['Biswajit'], axis=1, inplace=True)

# %%
ship
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 885          887       2                              Montvila, Rev. Juozas
# 886          888       1                       Graham, Miss. Margaret Edith
# 887          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 888          890       1                              Behr, Mr. Karl Howell
# 889          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
ship.head(10)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            6       3                                   Moran, Mr. James
# 5            7       1                            McCarthy, Mr. Timothy J
# 6            8       3                     Palsson, Master. Gosta Leonard
# 7            9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8           10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 9           11       3                    Sandstrom, Miss. Marguerite Rut
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN
# ...

# %%
ship.loc[40:50]
# Out:
#     PassengerId  Pclass                                               Name  \
# 40           42       2  Turpin, Mrs. William John Robert (Dorothy Ann ...
# 41           43       3                                Kraeff, Mr. Theodor
# 42           44       2           Laroche, Miss. Simonne Marie Anne Andree
# 43           45       3                      Devaney, Miss. Margaret Delia
# 44           46       3                           Rogers, Mr. William John
# 45           47       3                                  Lennon, Mr. Denis
# 46           48       3                          O'Driscoll, Miss. Bridget
# 47           49       3                                Samaan, Mr. Youssef
# 48           50       3      Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 49           51       3                         Panula, Master. Juha Niilo
# 50           52       3                       Nosworthy, Mr. Richard Cater
#
#        Sex   Age  SibSp  Parch           Ticket     Fare Cabin
# ...

# %%
ship.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890 entries, 0 to 889
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  890 non-null    int64
#  1   Pclass       890 non-null    int64
#  2   Name         890 non-null    object
#  3   Sex          890 non-null    object
#  4   Age          713 non-null    float64
#  5   SibSp        890 non-null    int64
#  6   Parch        890 non-null    int64
#  7   Ticket       890 non-null    object
#  8   Fare         890 non-null    float64
#  9   Cabin        204 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
ship[ship.Cabin.isnull()]
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 2              3       3                             Heikkinen, Miss. Laina
# 4              6       3                                   Moran, Mr. James
# 6              8       3                     Palsson, Master. Gosta Leonard
# 7              9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# ..           ...     ...                                                ...
# 883          885       3                             Sutehall, Mr. Henry Jr
# 884          886       3               Rice, Mrs. William (Margaret Norton)
# 885          887       2                              Montvila, Rev. Juozas
# 887          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
import numpy as np

# %%
ship.Cabin.replace(to_replace=np.nan, value='Unknown', inplace=True)

# %%
ship[ship.Cabin.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin]
# Index: []

# %%
ship
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 885          887       2                              Montvila, Rev. Juozas
# 886          888       1                       Graham, Miss. Margaret Edith
# 887          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 888          890       1                              Behr, Mr. Karl Howell
# 889          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
ship.Age.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 890 entries, 0 to 889
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 713 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
ship.Age.mean()
# Out:
# np.float64(29.691683029453014)

# %%
ship.Age.replace(np.nan,ship.Age.mean(), inplace=True)

# %%
ship
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 885          887       2                              Montvila, Rev. Juozas
# 886          888       1                       Graham, Miss. Margaret Edith
# 887          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 888          890       1                              Behr, Mr. Karl Howell
# 889          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
ship.Parch.fillna(ship.Parch.mean(), inplace=True)
# Out:
# /tmp/ipython-input-143-1204957555.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ship.Parch.fillna(ship.Parch.mean(), inplace=True)

# %%
ship
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 885          887       2                              Montvila, Rev. Juozas
# 886          888       1                       Graham, Miss. Margaret Edith
# 887          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 888          890       1                              Behr, Mr. Karl Howell
# 889          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
ship[ship.Age.duplicated()]
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 13            15       3      Vestrom, Miss. Hulda Amanda Adolfina  female
# 15            17       3                      Rice, Master. Eugene    male
# 16            18       2              Williams, Mr. Charles Eugene    male
# 18            20       3                   Masselmani, Mrs. Fatima  female
# 19            21       2                      Fynney, Mr. Joseph J    male
# ..           ...     ...                                       ...     ...
# 885          887       2                     Montvila, Rev. Juozas    male
# 886          888       1              Graham, Miss. Margaret Edith  female
# 887          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 888          890       1                     Behr, Mr. Karl Howell    male
# 889          891       3                       Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch      Ticket     Fare    Cabin
# ...

# %%
ship.Fare.drop_duplicates(inplace=True)

# %%
ship
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 885          887       2                              Montvila, Rev. Juozas
# 886          888       1                       Graham, Miss. Margaret Edith
# 887          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 888          890       1                              Behr, Mr. Karl Howell
# 889          891       3                                Dooley, Mr. Patrick
#
# ...
